# %% [markdown]
# # Data Management

# %% [markdown]
# ## The Data Life Cycle
#
# ![data_lifecycle](https://library.sydney.edu.au/research/data-management/images/xResearch_data_lifecycle_final_20150827.png.pagespeed.ic.VG8oRep6aH.png)
# From [University of Sydney Library](https://library.sydney.edu.au/research/data-management/research-data-management.html)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("66oNv_DJuPc")

# %% [markdown]
# ## Federal Agency Grant Requirements

# %% [markdown]
# ## Data Management Plans

# %% [markdown]
# ## Ontologies and Metadata Standards

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# ## Quick Note on De-identification & Ethics

# %% [markdown]
# ---
# ### Resources
#
# * Guides on Data and Data Sets: http://campusguides.lib.utah.edu/dataanddatasets
